# %% [markdown]
# # Simulations with reinforcement learning

# %% [markdown]
# In this notebook you can run simulations with 5 different reinforcement learning algorithms. There are different example buildings that can be simulated.
#
# <br>
#
# Things to focus on:
# -  Why is it making more sub_runs than episodes??
# -  There are only 10 episodes sub-files that stay. The rest is deleted??
# -  Better to make a list with the mean rewards, so we can make plots after running.
# -  Now, the room is always on temperature, how to see this. Weekends off? only on on working hours?

# %%
import sinergym
from sinergym.utils.callbacks import LoggerEvalCallback
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import LoggerWrapper
from datetime import datetime
import gym
from stable_baselines3 import DQN, DDPG, PPO, A2C, SAC, TD3 

from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np

# %% [markdown]
# Next you can set different variables for het simulation. You can choose the period that you want to simulate.
#
# (For now the year is always 1991, has something to do with the current weather file, which is standard in the environment. Can be changed later on)
#
# <br>
#
# You also set the reward function here. Now it is set to exponential.

# %%
#environment = "Eplus-demo-v1"
environment  = "Eplus-5Zone-hot-continuous-v1"
#environment = "Eplus-5Zone-mixed- continuous-v1"
episodes = 75
experiment_date = datetime.today().strftime('%Y-%m-%d %H:%M')

#choose the simulation period
begin_day = 1
begin_month = 1
begin_year = 2022
end_day = 1
end_month = 2
end_year = 2022


# register run name
name = F"{environment}-episodes_{episodes}({experiment_date})"

# Set to one month only to reduce running time
extra_params={'timesteps_per_hour' : 4,
              'runperiod' : (begin_day,begin_month,begin_year,end_day,end_month,end_year)}

#env = gym.make(environment, config_params=extra_params)

env = gym.make(environment, reward=ExpReward ,config_params = extra_params
                                                ,
                                                reward_kwargs={
                                                                    'temperature_variable': 'Zone Air Temperature (SPACE1-1)',
                                                                    'energy_variable': 'Facility Total HVAC Electricity Demand Rate(Whole Building)',
                                                                    'range_comfort_winter': (20.0, 24.0),
                                                                    'range_comfort_summer': (22.0, 26.0),
                                                                    'energy_weight': 0.5})
# Out:
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,731] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,887] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:10,940] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,153] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-03 16:51:11,242] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %% [markdown]
# We can add also a Wrapper to the environment, we are going to use a Logger (extension of ``gym.Wrapper``) this is used to monitor and log the interactions with the environment and save the data into a CSV.
#
# <br>
#
# Need to change the output of the monitor file more. I want the temperatures for all the thermal zones. Now only space1-1 is shown.
#
# <br>
#
#
# CHECK HOW TO DO THIS

# %%
env = LoggerWrapper(env)

# %% [markdown]
# At this point we have the environment all set up and ready to be used to define and create our learning model in this case it's going to be a DQN, but we can use any other (have a look at the `DRL_battery.py` and read :ref:`Deep Reinforcement Learning Integration` for more detailed information on available DRL algorithms).
#
# You can choose the following algorithms:
# - DQN
# - DDPG
# - A2C
# - PPO
# - SAC
# - TD3

# %%
#model = DQN('MlpPolicy', env, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = A2C('MlpPolicy', env, verbose=1)

# %% [markdown]
# Now we need to calculate the number of timesteps of each episode for the evaluation.

# %%
n_timesteps_episode = env.simulator._eplus_one_epi_len / \
                      env.simulator._eplus_run_stepsize
#n_timesteps_episode = 300

print(n_timesteps_episode)
print((4*24*365)/12+(4*24))
# Out:
# 3072.0
# 3016.0

# %% [markdown]
# Now we need to create a vectorized wrapper for the environment because the callbacks we are going to use require a vector.

# %%
env_vec = DummyVecEnv([lambda: env])

# %% [markdown]
# We are going to use the LoggerEval callback to print and save the best model evaluated during training.

# %%
callbacks = []

# Set up Evaluation and saving best model
eval_callback = LoggerEvalCallback(
    env_vec,
    best_model_save_path='best_model/' + name + '/',
    log_path='best_model/' + name + '/',
    eval_freq=n_timesteps_episode * 2,
    deterministic=True,
    render=False,
    n_eval_episodes=2)
callbacks.append(eval_callback)

callback = CallbackList(callbacks)

# %% [markdown]
# This is the number of total time steps for the training.

# %%
timesteps = episodes * n_timesteps_episode
print(timesteps)
# Out:
# 230400.0

# %%
print(env.get_zones())
# Out:
# ['plenum-1', 'space1-1', 'space2-1', 'space3-1', 'space4-1', 'space5-1']

# %%
l

# %% [markdown]
# Now you can train the model with the callbacks defined earlier. Takes a lot of runnig time.
#
# <br>
#
# For two months and 6 episodes it is taking 17,5 mins
#
# Two months 3 episodes is almost 8 min
#
# One month 50 episodes is 108 min (126 sub_runs created)
#
#
# PPO, one month 100 episodes: 205 minutes
#
# PPO, one month, 10 episodes: +- 20 min

# %%
model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=1)
# Out:
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run1
# [2023-01-03 16:51:21,651] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-
EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run6
# Eval num_timesteps=6144, episode_reward=-364.92 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# New best mean reward!
# -------------------------------------------
# | eval/                     |             |
# |    comfort_penalty        | 0           |
# |    comfort_violation(%)   | 0           |
# |    mean_ep_length         | 3.07e+03    |
# |    mean_power_consumption | 6.63e+06    |
# |    mean_rewards           | -364.91562  |
# |    power_penalty          | -663        |
# |    std_rewards            | 0.0         |
# | rollout/                  |             |
# |    ep_len_mean            | 3.07e+03    |
# |    ep_rew_mean            | -613        |
# | time/                     |             |
# |    fps                    | 23          |
# |    iterations             | 3           |
# |    time_elapsed           | 257         |
# |    total_timesteps        | 6144        |
# | train/                    |             |
# |    approx_kl              | 0.007946392 |
# |    clip_fraction          | 0.0737      |
# |    clip_range             | 0.2         |
# |    entropy_loss           | -2.8        |
# |    explained_variance     | 0.218       |
# |    learning_rate          | 0.0003      |
# |    loss                   | 0.718       |
# |    n_updates              | 20          |
# |    policy_gradient_loss   | -0.00803    |
# |    std                    | 0.98        |
# |    value_loss             | 2.45        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.07e+03     |
# |    ep_rew_mean          | -613         |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 4            |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0088766655 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.338        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0091      |
# |    std                  | 0.964        |
# |    value_loss           | 2.38         |
# ------------------------------------------
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,348] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,449] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# [2023-01-03 16:56:43,974] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run7
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -592        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 5           |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009912675 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.672       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0083     |
# |    std                  | 0.955       |
# |    value_loss           | 1.77        |
# -----------------------------------------
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:42,968] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,038] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:57:43,383] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-
EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:59:29,773] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:59:29,773] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:59:29,773] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 16:59:30,314] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run11
# ...
# [2023-01-03 21:34:22,202] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run184
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:37,433] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:36:38,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run185
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:20,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# [2023-01-03 21:37:21,879] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run186
# Eval num_timesteps=227328, episode_reward=-318.90 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -------------------------------------------
# | eval/                     |             |
# |    comfort_penalty        | 0           |
# |    comfort_violation(%)   | 0           |
# |    mean_ep_length         | 3.07e+03    |
# |    mean_power_consumption | 5.8e+06     |
# |    mean_rewards           | -318.90036  |
# |    power_penalty          | -580        |
# |    std_rewards            | 0.0         |
# | rollout/                  |             |
# |    ep_len_mean            | 3.07e+03    |
# |    ep_rew_mean            | -367        |
# | time/                     |             |
# |    fps                    | 13          |
# |    iterations             | 111         |
# |    time_elapsed           | 17164       |
# |    total_timesteps        | 227328      |
# | train/                    |             |
# |    approx_kl              | 0.013041101 |
# |    clip_fraction          | 0.096       |
# |    clip_range             | 0.2         |
# |    entropy_loss           | -1.73       |
# |    explained_variance     | 0.891       |
# |    learning_rate          | 0.0003      |
# |    loss                   | 0.426       |
# |    n_updates              | 1100        |
# |    policy_gradient_loss   | 0.00169     |
# |    std                    | 0.58        |
# |    value_loss             | 0.988       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 112         |
# |    time_elapsed         | 17197       |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.016914528 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.002      |
# |    std                  | 0.574       |
# |    value_loss           | 0.675       |
# -----------------------------------------
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,453] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,497] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# [2023-01-03 21:38:12,884] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res11/Eplus-env-sub_run187
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -367        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 113         |
# |    time_elapsed         | 17230       |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.009497294 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.484       |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00203    |
# |    std                  | 0.573       |
# |    value_loss           | 0.968       |
# -----------------------------------------

# %%
model.save(env.simulator._env_working_dir_parent + '/' + name)

# %%
env.close()
# Out:
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-03 21:43:55,690] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
