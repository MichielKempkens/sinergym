# %% [markdown]
# # Simulations with reinforcement learning

# %% [markdown]
# In this notebook you can run simulations with 5 different reinforcement learning algorithms. There are different example buildings that can be simulated.
#
# <br>
#
# Things to focus on:
# -  Why is it making more sub_runs than episodes??
# -  There are only 10 episodes sub-files that stay. The rest is deleted??
# -  Better to make a list with the mean rewards, so we can make plots after running.
# -  Now, the room is always on temperature, how to see this. Weekends off? only on on working hours?

# %%
import sinergym
from sinergym.utils.callbacks import LoggerEvalCallback
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import LoggerWrapper
from datetime import datetime
import gym
from stable_baselines3 import DQN, DDPG, PPO, A2C, SAC, TD3 

from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np

# %% [markdown]
# Next you can set different variables for het simulation. You can choose the period that you want to simulate.
#
# (For now the year is always 1991, has something to do with the current weather file, which is standard in the environment. Can be changed later on)
#
# <br>
#
# You also set the reward function here. Now it is set to exponential.

# %%
#environment = "Eplus-demo-v1"
environment  = "Eplus-5Zone-hot-continuous-v1"
#environment = "Eplus-5Zone-mixed- continuous-v1"
weather = "USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw"



episodes = 25
experiment_date = datetime.today().strftime('%Y-%m-%d %H:%M')

#choose the simulation period
begin_day = 1
begin_month = 1
begin_year = 2022
end_day = 1
end_month = 2
end_year = 2022


# register run name
name = F"{environment}-episodes_{episodes}({experiment_date})"

# Set to one month only to reduce running time
extra_params={'timesteps_per_hour' : 4,
              'runperiod' : (begin_day,begin_month,begin_year,end_day,end_month,end_year)}

#env = gym.make(environment, config_params=extra_params)



env = gym.make(environment, weather_file = weather,reward=ExpReward ,config_params = extra_params)
                                                # ,
                                                # reward_kwargs={
                                                #                     'temperature_variable': 'Zone Air Temperature (SPACE1-1)',
                                                #                     'energy_variable': 'Facility Total HVAC Electricity Demand Rate(Whole Building)',
                                                #                     'range_comfort_winter': (20.0, 23.5),
                                                #                     'range_comfort_summer': (22.0, 26.0)})
                                                                    #,'energy_weight': 0.5})
# Out:
# [2023-01-05 09:46:56,682] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-05 09:46:56,682] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-05 09:46:56,682] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-05 09:46:56,682] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-05 09:46:56,682] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-05 09:46:56,682] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-05 09:46:56,708] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-05 09:46:56,708] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-05 09:46:56,708] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-05 09:46:56,708] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-05 09:46:56,708] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-05 09:46:56,708] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-05 09:46:56,792] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-05 09:46:56,792] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-05 09:46:56,792] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-05 09:46:56,792] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-05 09:46:56,792] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-05 09:46:56,792] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-05 09:46:56,865] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-05 09:46:56,865] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-05 09:46:56,865] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-05 09:46:56,865] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-05 09:46:56,865] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-05 09:46:56,865] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-05 09:46:56,890] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-05 09:46:56,890] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-05 09:46:56,890] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-05 09:46:56,890] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-05 09:46:56,890] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-05 09:46:56,890] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %% [markdown]
# We can add also a Wrapper to the environment, we are going to use a Logger (extension of ``gym.Wrapper``) this is used to monitor and log the interactions with the environment and save the data into a CSV.
#
# <br>
#
# Need to change the output of the monitor file more. I want the temperatures for all the thermal zones. Now only space1-1 is shown.
#
# <br>
#
#
# CHECK HOW TO DO THIS

# %%
env = LoggerWrapper(env)

# %% [markdown]
# At this point we have the environment all set up and ready to be used to define and create our learning model in this case it's going to be a DQN, but we can use any other (have a look at the `DRL_battery.py` and read :ref:`Deep Reinforcement Learning Integration` for more detailed information on available DRL algorithms).
#
# You can choose the following algorithms:
# - DQN
# - DDPG
# - A2C
# - PPO
# - SAC
# - TD3

# %%
#model = DQN('MlpPolicy', env, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = A2C('MlpPolicy', env, verbose=1)

# %% [markdown]
# Now we need to calculate the number of timesteps of each episode for the evaluation.

# %%
n_timesteps_episode = env.simulator._eplus_one_epi_len / \
                      env.simulator._eplus_run_stepsize
#n_timesteps_episode = 300

print(n_timesteps_episode)
print((4*24*365)/12+(4*24))
# Out:
# 3072.0
# 3016.0

# %% [markdown]
# Now we need to create a vectorized wrapper for the environment because the callbacks we are going to use require a vector.

# %%
env_vec = DummyVecEnv([lambda: env])

# %% [markdown]
# We are going to use the LoggerEval callback to print and save the best model evaluated during training.

# %%
callbacks = []

# Set up Evaluation and saving best model
eval_callback = LoggerEvalCallback(
    env_vec,
    best_model_save_path='best_model/' + name + '/',
    log_path='best_model/' + name + '/',
    eval_freq=n_timesteps_episode * 2,
    deterministic=True,
    render=False,
    n_eval_episodes=2)
callbacks.append(eval_callback)

callback = CallbackList(callbacks)

# %% [markdown]
# This is the number of total time steps for the training.

# %%
timesteps = episodes * n_timesteps_episode
print(timesteps)
# Out:
# 76800.0

# %%
print(env.get_zones())
# Out:
# ['plenum-1', 'space1-1', 'space2-1', 'space3-1', 'space4-1', 'space5-1']

# %% [markdown]
# Now you can train the model with the callbacks defined earlier. Takes a lot of runnig time.
#
# <br>
#
# For two months and 6 episodes it is taking 17,5 mins
#
# Two months 3 episodes is almost 8 min
#
# One month 50 episodes is 108 min (126 sub_runs created)
#
#
# PPO, one month 100 episodes: 205 minutes
#
# PPO, one month, 10 episodes: +- 20 min
#
# PPO, one month, 200 episodes: 576 min

# %%
model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=1)
# Out:
# [2023-01-05 09:47:05,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:47:05,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:47:05,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:47:05,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:47:05,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:47:05,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:47:05,955] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-05 09:47:05,955] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-05 09:47:05,955] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-05 09:47:05,955] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-05 09:47:05,955] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-05 09:47:05,955] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# -----------------------------
# | time/              |      |
# |    fps             | 35   |
# |    iterations      | 1    |
# |    time_elapsed    | 56   |
# |    total_timesteps | 2048 |
# -----------------------------
# [2023-01-05 09:48:32,746] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:48:32,746] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:48:32,746] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:48:32,746] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:48:32,746] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:48:32,746] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:48:32,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:48:32,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:48:32,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:48:32,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:48:32,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:48:32,809] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:48:33,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-05 09:48:33,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-05 09:48:33,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-05 09:48:33,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-05 09:48:33,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-05 09:48:33,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -5.08e+03   |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 2           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009550761 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.000555    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 410         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.01        |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# [2023-01-05 09:49:28,647] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:28,647] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:28,647] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:28,647] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:28,647] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:28,647] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:28,688] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:28,688] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:28,688] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:28,688] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:28,688] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:28,688] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:29,055] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-05 09:49:29,055] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-05 09:49:29,055] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-05 09:49:29,055] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-05 09:49:29,055] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-05 09:49:29,055] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2023-01-05 09:49:42,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:42,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:42,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:42,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:42,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:42,303] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:49:42,402] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:42,402] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:42,402] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:42,402] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:42,402] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:42,402] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:49:42,996] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-05 09:49:42,996] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-05 09:49:42,996] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-05 09:49:42,996] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-05 09:49:42,996] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-05 09:49:42,996] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-05 09:50:29,871] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:50:29,871] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:50:29,871] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:50:29,871] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:50:29,871] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:50:29,871] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:50:29,907] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:50:29,907] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:50:29,907] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:50:29,907] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:50:29,907] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:50:29,907] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:50:30,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-05 09:50:30,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-05 09:50:30,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-05 09:50:30,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-05 09:50:30,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-05 09:50:30,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-05 09:51:17,772] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:51:17,772] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:51:17,772] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:51:17,772] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:51:17,772] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:51:17,772] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:51:17,788] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:51:17,788] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:51:17,788] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:51:17,788] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:51:17,788] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:51:17,788] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:51:18,253] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-05 09:51:18,253] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-05 09:51:18,253] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-05 09:51:18,253] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-05 09:51:18,253] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-05 09:51:18,253] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# Eval num_timesteps=6144, episode_reward=-3408.21 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# New best mean reward!
# -------------------------------------------
# | eval/                     |             |
# |    comfort_penalty        | -4.25e+03   |
# |    comfort_violation(%)   | 76.1        |
# |    mean_ep_length         | 3.07e+03    |
# |    mean_power_consumption | 2.57e+07    |
# |    mean_rewards           | -3408.2112  |
# |    power_penalty          | -2.57e+03   |
# |    std_rewards            | 0.0         |
# | rollout/                  |             |
# |    ep_len_mean            | 3.07e+03    |
# |    ep_rew_mean            | -5.17e+03   |
# | time/                     |             |
# |    fps                    | 22          |
# |    iterations             | 3           |
# |    time_elapsed           | 269         |
# |    total_timesteps        | 6144        |
# | train/                    |             |
# |    approx_kl              | 0.010529529 |
# |    clip_fraction          | 0.125       |
# |    clip_range             | 0.2         |
# |    entropy_loss           | -2.86       |
# |    explained_variance     | 0.025       |
# |    learning_rate          | 0.0003      |
# |    loss                   | 136         |
# |    n_updates              | 20          |
# |    policy_gradient_loss   | -0.0105     |
# |    std                    | 1.01        |
# |    value_loss             | 443         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.07e+03     |
# |    ep_rew_mean          | -5.17e+03    |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 4            |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0063722967 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 3.04e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.88e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 1.02         |
# |    value_loss           | 2.7e+03      |
# ------------------------------------------
# [2023-01-05 09:52:33,478] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:52:33,478] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:52:33,478] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:52:33,478] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:52:33,478] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:52:33,478] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:52:33,509] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:52:33,509] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:52:33,509] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:52:33,509] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:52:33,509] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:52:33,509] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:52:33,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-05 09:52:33,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-05 09:52:33,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-05 09:52:33,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-05 09:52:33,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-05 09:52:33,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -4.62e+03   |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 5           |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006147994 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.000268    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 209         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00622    |
# |    std                  | 1.02        |
# |    value_loss           | 439         |
# -----------------------------------------
# [2023-01-05 09:53:43,197] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:53:43,197] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:53:43,197] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:53:43,197] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:53:43,197] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:53:43,197] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:53:43,211] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:53:43,211] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:53:43,211] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:53:43,211] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:53:43,211] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:53:43,211] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:53:43,479] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-05 09:53:43,479] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-05 09:53:43,479] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-05 09:53:43,479] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-05 09:53:43,479] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-05 09:53:43,479] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-05 09:54:00,069] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:00,069] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:00,069] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:00,069] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:00,069] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:00,069] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:00,100] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:00,100] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:00,100] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:00,100] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:00,100] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:00,100] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:00,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-05 09:54:00,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-05 09:54:00,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-05 09:54:00,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-05 09:54:00,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-05 09:54:00,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-05 09:54:58,868] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:58,868] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:58,868] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:58,868] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:58,868] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:58,868] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:54:58,905] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:58,905] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:58,905] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:58,905] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:58,905] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:58,905] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:54:59,333] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-05 09:54:59,333] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-05 09:54:59,333] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-05 09:54:59,333] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-05 09:54:59,333] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-05 09:54:59,333] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-05 09:55:43,828] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:55:43,828] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:55:43,828] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:55:43,828] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:55:43,828] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:55:43,828] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:55:43,947] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:55:43,947] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:55:43,947] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:55:43,947] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:55:43,947] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:55:43,947] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:55:44,531] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-05 09:55:44,531] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-05 09:55:44,531] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-05 09:55:44,531] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-05 09:55:44,531] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-05 09:55:44,531] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# Eval num_timesteps=12288, episode_reward=-2269.34 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# New best mean reward!
# -------------------------------------------
# | eval/                     |             |
# |    comfort_penalty        | -1.1e+03    |
# |    comfort_violation(%)   | 11.1        |
# |    mean_ep_length         | 3.07e+03    |
# |    mean_power_consumption | 3.43e+07    |
# |    mean_rewards           | -2269.34    |
# |    power_penalty          | -3.43e+03   |
# |    std_rewards            | 0.0         |
# | rollout/                  |             |
# |    ep_len_mean            | 3.07e+03    |
# |    ep_rew_mean            | -4.24e+03   |
# | time/                     |             |
# |    fps                    | 23          |
# |    iterations             | 6           |
# |    time_elapsed           | 527         |
# |    total_timesteps        | 12288       |
# | train/                    |             |
# |    approx_kl              | 0.008381734 |
# |    clip_fraction          | 0.0881      |
# |    clip_range             | 0.2         |
# |    entropy_loss           | -2.84       |
# |    explained_variance     | 0.0017      |
# |    learning_rate          | 0.0003      |
# |    loss                   | 39.5        |
# |    n_updates              | 50          |
# |    policy_gradient_loss   | -0.00692    |
# |    std                    | 0.988       |
# |    value_loss             | 110         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -4.24e+03   |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 7           |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005801337 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.000998    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 244         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00346    |
# |    std                  | 0.978       |
# |    value_loss           | 243         |
# -----------------------------------------
# [2023-01-05 09:56:53,006] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:56:53,006] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:56:53,006] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:56:53,006] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:56:53,006] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:56:53,006] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:56:53,078] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:56:53,078] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:56:53,078] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:56:53,078] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:56:53,078] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:56:53,078] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:56:53,897] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-05 09:56:53,897] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-05 09:56:53,897] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-05 09:56:53,897] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-05 09:56:53,897] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-05 09:56:53,897] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.07e+03     |
# |    ep_rew_mean          | -4.02e+03    |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 8            |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0055758827 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0181       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 215          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00357     |
# |    std                  | 0.977        |
# |    value_loss           | 338          |
# ------------------------------------------
# [2023-01-05 09:58:21,126] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:21,126] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:21,126] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:21,126] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:21,126] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:21,126] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:21,148] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:21,148] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:21,148] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:21,148] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:21,148] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:21,148] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:21,518] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-05 09:58:21,518] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-05 09:58:21,518] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-05 09:58:21,518] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-05 09:58:21,518] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-05 09:58:21,518] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-05 09:58:42,661] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:42,661] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:42,661] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:42,661] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:42,661] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:42,661] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:58:42,703] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:42,703] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:42,703] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:42,703] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:42,703] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:42,703] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:58:43,286] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-05 09:58:43,286] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-05 09:58:43,286] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-05 09:58:43,286] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-05 09:58:43,286] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-05 09:58:43,286] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-05 09:59:42,279] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:59:42,279] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:59:42,279] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:59:42,279] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:59:42,279] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:59:42,279] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 09:59:42,312] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:59:42,312] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:59:42,312] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:59:42,312] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:59:42,312] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:59:42,312] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 09:59:42,787] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run15
# ...
# [2023-01-05 10:35:21,957] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:21,957] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:21,957] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:22,979] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run58
# [2023-01-05 10:35:22,979] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run58
# [2023-01-05 10:35:22,979] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run58
# [2023-01-05 10:35:22,979] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run58
# [2023-01-05 10:35:22,979] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run58
# [2023-01-05 10:35:22,979] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run58
# [2023-01-05 10:35:40,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:35:40,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:35:40,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:35:40,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:35:40,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:35:40,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:35:40,284] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:40,284] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:40,284] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:40,284] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:40,284] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:40,284] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:35:40,936] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run59
# [2023-01-05 10:35:40,936] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run59
# [2023-01-05 10:35:40,936] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run59
# [2023-01-05 10:35:40,936] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run59
# [2023-01-05 10:35:40,936] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run59
# [2023-01-05 10:35:40,936] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run59
# [2023-01-05 10:36:35,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:36:35,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:36:35,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:36:35,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:36:35,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:36:35,747] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:36:35,866] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:36:35,866] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:36:35,866] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:36:35,866] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:36:35,866] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:36:35,866] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:36:36,356] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run60
# [2023-01-05 10:36:36,356] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run60
# [2023-01-05 10:36:36,356] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run60
# [2023-01-05 10:36:36,356] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run60
# [2023-01-05 10:36:36,356] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run60
# [2023-01-05 10:36:36,356] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run60
# [2023-01-05 10:37:22,826] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:37:22,826] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:37:22,826] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:37:22,826] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:37:22,826] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:37:22,826] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:37:22,860] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:37:22,860] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:37:22,860] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:37:22,860] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:37:22,860] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:37:22,860] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:37:23,582] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run61
# [2023-01-05 10:37:23,582] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run61
# [2023-01-05 10:37:23,582] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run61
# [2023-01-05 10:37:23,582] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run61
# [2023-01-05 10:37:23,582] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run61
# [2023-01-05 10:37:23,582] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run61
# Eval num_timesteps=73728, episode_reward=-2173.37 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# --------------------------------------------
# | eval/                     |              |
# |    comfort_penalty        | -172         |
# |    comfort_violation(%)   | 3.61         |
# |    mean_ep_length         | 3.07e+03     |
# |    mean_power_consumption | 4.17e+07     |
# |    mean_rewards           | -2173.3696   |
# |    power_penalty          | -4.17e+03    |
# |    std_rewards            | 0.0          |
# | rollout/                  |              |
# |    ep_len_mean            | 3.07e+03     |
# |    ep_rew_mean            | -2.69e+03    |
# | time/                     |              |
# |    fps                    | 24           |
# |    iterations             | 36           |
# |    time_elapsed           | 3024         |
# |    total_timesteps        | 73728        |
# | train/                    |              |
# |    approx_kl              | 0.0054817754 |
# |    clip_fraction          | 0.0814       |
# |    clip_range             | 0.2          |
# |    entropy_loss           | -2.55        |
# |    explained_variance     | 0.363        |
# |    learning_rate          | 0.0003       |
# |    loss                   | 20.9         |
# |    n_updates              | 350          |
# |    policy_gradient_loss   | -0.000311    |
# |    std                    | 0.865        |
# |    value_loss             | 46.2         |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.07e+03     |
# |    ep_rew_mean          | -2.69e+03    |
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 37           |
# |    time_elapsed         | 3086         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0028954768 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50           |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000476     |
# |    std                  | 0.863        |
# |    value_loss           | 55.2         |
# ------------------------------------------
# [2023-01-05 10:38:57,063] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:38:57,063] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:38:57,063] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:38:57,063] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:38:57,063] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:38:57,063] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-05 10:38:57,136] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:38:57,136] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:38:57,136] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:38:57,136] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:38:57,136] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:38:57,136] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-05 10:39:00,327] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62
# [2023-01-05 10:39:00,327] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62
# [2023-01-05 10:39:00,327] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62
# [2023-01-05 10:39:00,327] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62
# [2023-01-05 10:39:00,327] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62
# [2023-01-05 10:39:00,327] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.07e+03    |
# |    ep_rew_mean          | -2.67e+03   |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 38          |
# |    time_elapsed         | 3158        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.018142454 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00204     |
# |    std                  | 0.856       |
# |    value_loss           | 30.4        |
# -----------------------------------------

# %%
model.save(env.simulator._env_working_dir_parent + '/' + name)|

# %%
env.close()|
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [60], line 1
# ----> 1 env.close()
#
# File /sinergym/sinergym/utils/wrappers.py:277, in LoggerWrapper.close(self)
#     274 # Record last episode summary before end simulation
#     275 self.env.simulator.logger_main.debug(
#     276     'End of episode, recording summary (progress.csv) if logger is active')
# --> 277 self.logger.log_episode(episode=self.env.simulator._epi_num)
#     279 # Then, close env
#     280 self.env.close()
#
# File /sinergym/sinergym/utils/logger.py:252, in CSVLogger.log_episode(self, episode)
#     249     comfort_violation = np.nan
#     251 # write steps_info in monitor.csv
# --> 252 with open(self.log_file, 'w', newline='') as file_obj:
#     253     # Create a writer object from csv module
#     254     csv_writer = csv.writer(file_obj)
#     255     # Add contents of list as last row in the csv file
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run62/monitor.csv'
