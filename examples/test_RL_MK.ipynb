# %% [markdown]
# # Simulations with reinforcement learning

# %% [markdown]
# In this notebook you can run simulations with 5 different reinforcement learning algorithms. There are different example buildings that can be simulated.
#
# <br>
#
# Things to focus on:
# -  Why is it making more sub_runs than episodes??
# -  There are only 10 episodes sub-files that stay. The rest is deleted??
# -  Better to make a list with the mean rewards, so we can make plots after running.
# -  Now, the room is always on temperature, how to see this. Weekends off? only on on working hours?

# %%
import sinergym
from sinergym.utils.callbacks import LoggerEvalCallback
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import LoggerWrapper
from datetime import datetime
import gym
from stable_baselines3 import DQN, DDPG, PPO, A2C, SAC, TD3 

from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %% [markdown]
# Next you can set different variables for het simulation. You can choose the period that you want to simulate.
#
# (For now the year is always 1991, has something to do with the current weather file, which is standard in the environment. Can be changed later on)
#
# <br>
#
# You also set the reward function here. Now it is set to exponential.

# %%
environment = "Eplus-demo-v1"
#environment  = "Eplus-5Zone-hot-continuous-v1"
episodes = 25
experiment_date = datetime.today().strftime('%Y-%m-%d %H:%M')

#choose the simulation period
begin_day = 1
begin_month = 1
begin_year = 2022
end_day = 1
end_month = 2
end_year = 2022


# register run name
name = F"{environment}-episodes_{episodes}({experiment_date})"

# Set to one month only to reduce running time
extra_params={'timesteps_per_hour' : 4,
              'runperiod' : (begin_day,begin_month,begin_year,end_day,end_month,end_year)}

#env = gym.make(environment, config_params=extra_params)

env = gym.make(environment, reward=ExpReward ,config_params = extra_params)
                                                # ,
                                                # reward_kwargs={
                                                #                     # 'temperature_variable': 'Zone Air Temperature (SPACE1-1)',
                                                #                     # 'energy_variable': 'Facility Total HVAC Electricity Demand Rate (Whole Building)',
                                                #                     'range_comfort_winter': (21.0, 25),
                                                #                     'range_comfort_summer': (23.0, 26.0),
                                                #                     'energy_weight': 0.1})
# Out:
# [2023-01-02 13:42:06,700] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-02 13:42:06,700] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-02 13:42:06,700] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-02 13:42:06,700] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-02 13:42:06,700] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-02 13:42:06,749] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-02 13:42:06,749] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-02 13:42:06,749] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-02 13:42:06,749] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-02 13:42:06,749] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-02 13:42:06,781] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-02 13:42:06,781] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-02 13:42:06,781] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-02 13:42:06,781] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-02 13:42:06,781] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-02 13:42:06,882] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-02 13:42:06,882] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-02 13:42:06,882] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-02 13:42:06,882] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-02 13:42:06,882] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-02 13:42:06,935] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-02 13:42:06,935] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-02 13:42:06,935] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-02 13:42:06,935] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-02 13:42:06,935] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...

# %% [markdown]
# We can add also a Wrapper to the environment, we are going to use a Logger (extension of ``gym.Wrapper``) this is used to monitor and log the interactions with the environment and save the data into a CSV.
#
# <br>
#
# Need to change the output of the monitor file more. I want the temperatures for all the thermal zones. Now only space1-1 is shown.
#
# <br>
#
#
# CHECK HOW TO DO THIS

# %%
env = LoggerWrapper(env)

# %% [markdown]
# At this point we have the environment all set up and ready to be used to define and create our learning model in this case it's going to be a DQN, but we can use any other (have a look at the `DRL_battery.py` and read :ref:`Deep Reinforcement Learning Integration` for more detailed information on available DRL algorithms).
#
# You can choose the following algorithms:
# - DQN
# - DDPG
# - A2C
# - PPO
# - SAC
# - TD3

# %%
model = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = A2C('MlpPolicy', env, verbose=1)

# %% [markdown]
# Now we need to calculate the number of timesteps of each episode for the evaluation.

# %%
n_timesteps_episode = env.simulator._eplus_one_epi_len / \
                      env.simulator._eplus_run_stepsize
#n_timesteps_episode = 300

print(n_timesteps_episode)
print(4*24*365)
# Out:
# 3072.0
# 35040

# %% [markdown]
# Now we need to create a vectorized wrapper for the environment because the callbacks we are going to use require a vector.

# %%
env_vec = DummyVecEnv([lambda: env])

# %% [markdown]
# We are going to use the LoggerEval callback to print and save the best model evaluated during training.

# %%
callbacks = []

# Set up Evaluation and saving best model
eval_callback = LoggerEvalCallback(
    env_vec,
    best_model_save_path='best_model/' + name + '/',
    log_path='best_model/' + name + '/',
    eval_freq=n_timesteps_episode * 2,
    deterministic=True,
    render=False,
    n_eval_episodes=2)
callbacks.append(eval_callback)

callback = CallbackList(callbacks)

# %% [markdown]
# This is the number of total time steps for the training.

# %%
timesteps = episodes * n_timesteps_episode
print(timesteps)
# Out:
# 76800.0

# %%
print(env.get_zones())
# Out:
# ['plenum-1', 'space1-1', 'space2-1', 'space3-1', 'space4-1', 'space5-1']

# %% [markdown]
# Now you can train the model with the callbacks defined earlier. Takes a lot of runnig time.
#
# <br>
#
# For two months and 6 episodes it is taking 17,5 mins
#
# Two months 3 episodes is almost 8 min
#
# One month 50 episodes is 108 min (126 sub_runs created)

# %%
model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=1)
# Out:
# [2023-01-02 13:42:32,742] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01
EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:01,194] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:01,194] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:01,194] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:01,194] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:01,220] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:01,220] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:01,220] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:01,220] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:01,220] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:01,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run5
# [2023-01-02 13:47:01,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run5
# [2023-01-02 13:47:01,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run5
# [2023-01-02 13:47:01,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run5
# [2023-01-02 13:47:01,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run5
# [2023-01-02 13:47:55,131] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:55,131] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:55,131] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:55,131] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:55,131] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:47:55,145] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:55,145] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:55,145] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:55,145] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:55,145] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:47:55,613] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run6
# [2023-01-02 13:47:55,613] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run6
# [2023-01-02 13:47:55,613] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run6
# [2023-01-02 13:47:55,613] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run6
# [2023-01-02 13:47:55,613] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run6
# Eval num_timesteps=6144, episode_reward=-2268.39 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -55.9     |
# |    comfort_violation(%)   | 1.14      |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 4.48e+07  |
# |    mean_rewards           | -2268.393 |
# |    power_penalty          | -4.48e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -4.32e+03 |
# |    exploration_rate       | 0.24      |
# | time/                     |           |
# |    episodes               | 2         |
# |    fps                    | 18        |
# |    time_elapsed           | 331       |
# |    total_timesteps        | 6144      |
# -----------------------------------------
# [2023-01-02 13:48:45,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:48:45,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:48:45,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:48:45,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:48:45,844] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:48:45,885] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:48:45,885] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:48:45,885] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:48:45,885] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:48:45,885] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:48:46,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run7
# [2023-01-02 13:48:46,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run7
# [2023-01-02 13:48:46,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run7
# [2023-01-02 13:48:46,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run7
# [2023-01-02 13:48:46,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run7
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 3.07e+03  |
# |    ep_rew_mean      | -4.31e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 3         |
# |    fps              | 24        |
# |    time_elapsed     | 380       |
# |    total_timesteps  | 9216      |
# -----------------------------------
# [2023-01-02 13:49:35,481] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:35,481] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:35,481] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:35,481] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:35,481] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:35,492] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:35,492] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:35,492] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:35,492] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:35,492] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:35,742] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run8
# [2023-01-02 13:49:35,742] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run8
# [2023-01-02 13:49:35,742] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run8
# [2023-01-02 13:49:35,742] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run8
# [2023-01-02 13:49:35,742] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run8
# [2023-01-02 13:49:49,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:49,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:49,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:49,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:49,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:49:49,128] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:49,128] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:49,128] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:49,128] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:49,128] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:49:49,480] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run9
# [2023-01-02 13:49:49,480] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run9
# [2023-01-02 13:49:49,480] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run9
# [2023-01-02 13:49:49,480] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run9
# [2023-01-02 13:49:49,480] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run9
# [2023-01-02 13:50:40,170] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:50:40,170] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:50:40,170] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:50:40,170] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:50:40,170] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:50:40,181] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:50:40,181] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:50:40,181] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:50:40,181] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:50:40,181] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:50:40,423] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run10
# [2023-01-02 13:50:40,423] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run10
# [2023-01-02 13:50:40,423] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run10
# [2023-01-02 13:50:40,423] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run10
# [2023-01-02 13:50:40,423] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run10
# [2023-01-02 13:51:23,675] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:51:23,675] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:51:23,675] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:51:23,675] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:51:23,675] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:51:23,685] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:51:23,685] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:51:23,685] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:51:23,685] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:51:23,685] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:51:24,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run11
# [2023-01-02 13:51:24,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run11
# [2023-01-02 13:51:24,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run11
# [2023-01-02 13:51:24,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run11
# [2023-01-02 13:51:24,011] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run11
# Eval num_timesteps=12288, episode_reward=-2268.39 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -55.9     |
# |    comfort_violation(%)   | 1.14      |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 4.48e+07  |
# |    mean_rewards           | -2268.393 |
# |    power_penalty          | -4.48e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -4.37e+03 |
# |    exploration_rate       | 0.05      |
# | time/                     |           |
# |    episodes               | 4         |
# |    fps                    | 22        |
# |    time_elapsed           | 535       |
# |    total_timesteps        | 12288     |
# -----------------------------------------
# [2023-01-02 13:52:00,452] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:52:00,452] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01
EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run16
# [2023-01-02 13:54:02,293] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run16
# [2023-01-02 13:54:02,293] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run16
# [2023-01-02 13:54:02,293] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run16
# Eval num_timesteps=18432, episode_reward=-2268.39 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -55.9     |
# |    comfort_violation(%)   | 1.14      |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 4.48e+07  |
# |    mean_rewards           | -2268.393 |
# |    power_penalty          | -4.48e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -4.35e+03 |
# |    exploration_rate       | 0.05      |
# | time/                     |           |
# |    episodes               | 6         |
# |    fps                    | 26        |
# |    time_elapsed           | 694       |
# |    total_timesteps        | 18432     |
# -----------------------------------------
# [2023-01-02 13:54:40,304] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:54:40,304] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:54:40,304] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:54:40,304] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:54:40,304] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:54:40,453] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:54:40,453] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:54:40,453] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:54:40,453] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:54:40,453] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:54:40,982] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run17
# [2023-01-02 13:54:40,982] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run17
# [2023-01-02 13:54:40,982] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run17
# [2023-01-02 13:54:40,982] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run17
# [2023-01-02 13:54:40,982] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run17
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 3.07e+03  |
# |    ep_rew_mean      | -4.41e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 7         |
# |    fps              | 29        |
# |    time_elapsed     | 731       |
# |    total_timesteps  | 21504     |
# -----------------------------------
# [2023-01-02 13:55:18,598] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:18,598] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:18,598] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:18,598] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:18,598] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:18,623] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:18,623] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:18,623] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:18,623] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:18,623] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:19,248] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run18
# [2023-01-02 13:55:19,248] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run18
# [2023-01-02 13:55:19,248] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run18
# [2023-01-02 13:55:19,248] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run18
# [2023-01-02 13:55:19,248] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run18
# [2023-01-02 13:55:29,430] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:29,430] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:29,430] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:29,430] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:29,430] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:55:29,463] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:29,463] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:29,463] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:29,463] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:29,463] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:55:29,925] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run19
# [2023-01-02 13:55:29,925] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run19
# [2023-01-02 13:55:29,925] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run19
# [2023-01-02 13:55:29,925] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run19
# [2023-01-02 13:55:29,925] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run19
# [2023-01-02 13:56:12,997] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:56:12,997] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:56:12,997] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:56:12,997] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:56:12,997] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:56:13,057] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:56:13,057] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:56:13,057] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:56:13,057] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:56:13,057] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:56:13,529] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run20
# [2023-01-02 13:56:13,529] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run20
# [2023-01-02 13:56:13,529] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run20
# [2023-01-02 13:56:13,529] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run20
# [2023-01-02 13:56:13,529] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run20
# [2023-01-02 13:57:11,546] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:11,546] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:11,546] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:11,546] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:11,546] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:11,562] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:11,562] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:11,562] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:11,562] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:11,562] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:12,233] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run21
# [2023-01-02 13:57:12,233] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run21
# [2023-01-02 13:57:12,233] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run21
# [2023-01-02 13:57:12,233] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run21
# [2023-01-02 13:57:12,233] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run21
# Eval num_timesteps=24576, episode_reward=-2268.39 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -55.9     |
# |    comfort_violation(%)   | 1.14      |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 4.48e+07  |
# |    mean_rewards           | -2268.393 |
# |    power_penalty          | -4.48e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -4.41e+03 |
# |    exploration_rate       | 0.05      |
# | time/                     |           |
# |    episodes               | 8         |
# |    fps                    | 27        |
# |    time_elapsed           | 886       |
# |    total_timesteps        | 24576     |
# -----------------------------------------
# [2023-01-02 13:57:54,309] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:54,309] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:54,309] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:54,309] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:54,309] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 13:57:54,318] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:54,318] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:54,318] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:54,318] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 13:57:54,318] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# ...
# [2023-01-02 14:18:36,841] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run56
# [2023-01-02 14:18:36,841] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run56
# [2023-01-02 14:18:36,841] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run56
# [2023-01-02 14:18:36,841] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run56
# [2023-01-02 14:18:36,841] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run56
# Eval num_timesteps=67584, episode_reward=-2303.59 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -16.2     |
# |    comfort_violation(%)   | 0.228     |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 4.59e+07  |
# |    mean_rewards           | -2303.594 |
# |    power_penalty          | -4.59e+03 |
EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run60
# [2023-01-02 14:21:21,988] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run60
# [2023-01-02 14:22:14,664] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:22:14,664] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:22:14,664] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:22:14,664] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:22:14,664] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:22:14,678] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:22:14,678] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:22:14,678] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:22:14,678] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:22:14,678] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:22:14,940] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run61
# [2023-01-02 14:22:14,940] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run61
# [2023-01-02 14:22:14,940] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run61
# [2023-01-02 14:22:14,940] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run61
# [2023-01-02 14:22:14,940] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run61
# Eval num_timesteps=73728, episode_reward=-2325.71 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# ------------------------------------------
# | eval/                     |            |
# |    comfort_penalty        | -441       |
# |    comfort_violation(%)   | 9.18       |
# |    mean_ep_length         | 3.07e+03   |
# |    mean_power_consumption | 4.21e+07   |
# |    mean_rewards           | -2325.7097 |
# |    power_penalty          | -4.21e+03  |
# |    std_rewards            | 0.0        |
# | rollout/                  |            |
# |    ep_len_mean            | 3.07e+03   |
# |    ep_rew_mean            | -3.77e+03  |
# |    exploration_rate       | 0.05       |
# | time/                     |            |
# |    episodes               | 24         |
# |    fps                    | 30         |
# |    time_elapsed           | 2387       |
# |    total_timesteps        | 73728      |
# | train/                    |            |
# |    learning_rate          | 0.0001     |
# |    loss                   | 15.1       |
# |    n_updates              | 5931       |
# ------------------------------------------
# [2023-01-02 14:23:34,738] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:23:34,738] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:23:34,738] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:23:34,738] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:23:34,738] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-02 14:23:34,839] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:23:34,839] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:23:34,839] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:23:34,839] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:23:34,839] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-02 14:23:35,316] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run62
# [2023-01-02 14:23:35,316] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run62
# [2023-01-02 14:23:35,316] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run62
# [2023-01-02 14:23:35,316] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run62
# [2023-01-02 14:23:35,316] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-demo-v1-res25/Eplus-env-sub_run62
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 3.07e+03  |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 25        |
# |    fps              | 31        |
# |    time_elapsed     | 2469      |
# |    total_timesteps  | 76800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 13.1      |
# |    n_updates        | 6699      |
# -----------------------------------

# %%
model.save(env.simulator._env_working_dir_parent + '/' + name)

# %%
env.close()
# Out:
# [2023-01-02 15:06:23,092] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-02 15:06:23,092] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-02 15:06:23,092] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-02 15:06:23,092] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-02 15:06:23,092] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
