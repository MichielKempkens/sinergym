# %% [markdown]
# # Simulations with reinforcement learning

# %% [markdown]
# In this notebook you can run simulations with 5 different reinforcement learning algorithms. There are different example buildings that can be simulated.
#
# <br>

# %%
import sinergym
from sinergym.utils.callbacks import LoggerEvalCallback
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import LoggerWrapper, NormalizeObservation
from sinergym.utils.constants import RANGES_5ZONE
from datetime import datetime
import gym
from stable_baselines3 import DQN, DDPG, PPO, A2C, SAC, TD3


from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np

from math import exp
from typing import Any, Dict, List, Tuple, Union
from gym import Env
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %% [markdown]
# # Reward functions

# %%
"""Implementation of reward functions."""


class BaseReward(object):

    def __init__(self, env):
        """
        Base reward class.

        All reward functions should inherit from this class.

        Args:
            env (Env): Gym environment.
        """
        self.env = env

    def __call__(self):
        """Method for calculating the reward function."""
        raise NotImplementedError(
            "Reward class must have a `__call__` method.")


class MyLinearReward(BaseReward):

    def __init__(
        self,
        env: Env,
        temperature_variable: Union[str, list],
        energy_variable: str,
        range_comfort_winter: Tuple[int, int],
        range_comfort_summer: Tuple[int, int],
        summer_start: Tuple[int, int] = (6, 1),
        summer_final: Tuple[int, int] = (9, 30),
        energy_weight: float = 0.5,
        #energy_weight: float = 1,
        lambda_energy: float = 1e-4,
        #lambda_energy: float = 1,
        lambda_temperature: float = 1.0
    ):
        """
        Linear reward function.

        It considers the energy consumption and the absolute difference to temperature comfort.

        .. math::
            R = - W * lambda_E * power - (1 - W) * lambda_T * (max(T - T_{low}, 0) + max(T_{up} - T, 0))

        Args:
            env (Env): Gym environment.
            temperature_variable (Union[str, list]): Name(s) of the temperature variable(s).
            energy_variable (str): Name of the energy/power variable.
            range_comfort_winter (Tuple[int,int]): Temperature comfort range for cold season. Depends on environment you are using.
            range_comfort_summer (Tuple[int,int]): Temperature comfort range for hot season. Depends on environment you are using.
            summer_start (Tuple[int,int]): Summer session tuple with month and day start. Defaults to (6,1).
            summer_final (Tuple[int,int]): Summer session tuple with month and day end. defaults to (9,30).
            energy_weight (float, optional): Weight given to the energy term. Defaults to 0.5.
            lambda_energy (float, optional): Constant for removing dimensions from power(1/W). Defaults to 1e-4.
            lambda_temperature (float, optional): Constant for removing dimensions from temperature(1/C). Defaults to 1.0.
        """

        super(MyLinearReward, self).__init__(env)

        # Name of the variables
        self.temp_name = temperature_variable
        self.energy_name = energy_variable

        # Reward parameters
        self.range_comfort_winter = range_comfort_winter
        self.range_comfort_summer = range_comfort_summer
        self.W_energy = energy_weight
        self.lambda_energy = lambda_energy
        self.lambda_temp = lambda_temperature

        # Summer period
        self.summer_start = summer_start  # (month,day)
        self.summer_final = summer_final  # (month,day)

    def __call__(self) -> Tuple[float, Dict[str, Any]]:
        """
        Calculate the reward function.

        Returns:
            Tuple[float, Dict[str, Any]]: Reward value and dictionary with their individual components.
        """
        # Current observation
        obs_dict = self.env.obs_dict.copy()

        # Energy term
        #reward_energy = - self.lambda_energy * obs_dict[self.energy_name]
        reward_energy = - self.lambda_energy * obs_dict[self.energy_name]

        # Comfort
        comfort, temps = self._get_comfort(obs_dict)
        reward_comfort = - self.lambda_temp * comfort

        # Weighted sum of both terms
        reward = self.W_energy * reward_energy + \
            (1.0 - self.W_energy) * reward_comfort

        reward_terms = {
            'reward_energy': reward_energy,
            'total_energy': obs_dict[self.energy_name],
            'reward_comfort': reward_comfort,
            'abs_comfort': comfort,
            'temperatures': temps
        }

        return reward, reward_terms

    def _get_comfort(self,
                     obs_dict: Dict[str,
                                    Any]) -> Tuple[float,
                                                   List[float]]:
        """Calculate the comfort term of the reward.

        Returns:
            Tuple[float, List[float]]: comfort penalty and List with temperatures used.
        """

        hour = obs_dict["hour"]
        month = obs_dict['month']
        day = obs_dict['day']
        year = obs_dict['year']
        current_dt = datetime(year, month, day)

        # Periods
        summer_start_date = datetime(
            year,
            self.summer_start[0],
            self.summer_start[1])
        summer_final_date = datetime(
            year,
            self.summer_final[0],
            self.summer_final[1])

        if current_dt >= summer_start_date and current_dt <= summer_final_date:
            if hour not in range(7,19):
                temp_range = (15,30)
            else:
                temp_range = self.range_comfort_summer 
        else:
            if hour not in range(7,19):
                temp_range = (15,30)
            else:
                temp_range = self.range_comfort_winter


        temps = [v for k, v in obs_dict.items() if k in self.temp_name]
        comfort = 0.0
        for T in temps:
            if T < temp_range[0] or T > temp_range[1]:
                comfort += min(abs(temp_range[0] - T), abs(T - temp_range[1]))

        return comfort, temps


class MyExpReward(MyLinearReward):

    def __init__(
        self,
        env: Env,
        temperature_variable: Union[str, list],
        energy_variable: str,
        range_comfort_winter: Tuple[int, int],
        range_comfort_summer: Tuple[int, int],
        summer_start: Tuple[int, int] = (6, 1),
        summer_final: Tuple[int, int] = (9, 30),
        #changes from 0.5 to 0.7
        energy_weight: float = 0.7,
        lambda_energy: float = 1e-4,
        lambda_temperature: float = 1.0
    ):
        """
        Reward considering exponential absolute difference to temperature comfort.

        .. math::
            R = - W * lambda_E * power - (1 - W) * lambda_T * exp( (max(T - T_{low}, 0) + max(T_{up} - T, 0)) )

        Args:
            env (Env): Gym environment.
            temperature_variable (Union[str, list]): Name(s) of the temperature variable(s).
            energy_variable (str): Name of the energy/power variable.
            range_comfort_winter (Tuple[int,int]): Temperature comfort range for cold season. Depends on environment you are using.
            range_comfort_summer (Tuple[int,int]): Temperature comfort range for hot season. Depends on environment you are using.
            summer_start (Tuple[int,int]): Summer session tuple with month and day start. Defaults to (6,1).
            summer_final (Tuple[int,int]): Summer session tuple with month and day end. defaults to (9,30).
            energy_weight (float, optional): Weight given to the energy term. Defaults to 0.5.
            lambda_energy (float, optional): Constant for removing dimensions from power(1/W). Defaults to 1e-4.
            lambda_temperature (float, optional): Constant for removing dimensions from temperature(1/C). Defaults to 1.0.
        """

        super(MyExpReward, self).__init__(
            env,
            temperature_variable,
            energy_variable,
            range_comfort_winter,
            range_comfort_summer,
            summer_start,
            summer_final,
            energy_weight,
            lambda_energy,
            lambda_temperature
        )

    def _get_comfort(self,
                     obs_dict: Dict[str,
                                    Any]) -> Tuple[float,
                                                   List[float]]:
        """Calculate the comfort term of the reward.

        Returns:
            Tuple[float, List[float]]: comfort penalty and List with temperatures used.
        """

        hour = obs_dict["hour"]
        month = obs_dict['month']
        day = obs_dict['day']
        year = obs_dict['year']
        current_dt = datetime(year, month, day)

        # Periods
        summer_start_date = datetime(
            year,
            self.summer_start[0],
            self.summer_start[1])
        summer_final_date = datetime(
            year,
            self.summer_final[0],
            self.summer_final[1])


        if current_dt >= summer_start_date and current_dt <= summer_final_date:
            if hour not in range(7,19):
                temp_range = (15,30)
            else:
                temp_range = self.range_comfort_summer 
        else:
            if hour not in range(7,19):
                temp_range = (15,30)
            else:
                temp_range = self.range_comfort_winter


        temps = [v for k, v in obs_dict.items() if k in self.temp_name]
        comfort = 0.0
        for T in temps:
            if T < temp_range[0] or T > temp_range[1]:
                comfort += exp(min(abs(temp_range[0] - T),
                                   abs(T - temp_range[1])))



        return comfort, temps


class MyHourlyExpReward(MyExpReward):

    def __init__(
        self,
        env: Env,
        temperature_variable: Union[str, list],
        energy_variable: str,
        # range_comfort_winter: Tuple[int, int],
        # range_comfort_summer: Tuple[int, int],
        range_comfort_winter = (20,23.5),
        range_comfort_summer = (23,26),
        summer_start: Tuple[int, int] = (6, 1),
        summer_final: Tuple[int, int] = (9, 30),
        min_energy_weight: float = 0.5,
        lambda_energy: float = 1e-4,
        lambda_temperature: float = 1.0,
        range_comfort_hours: tuple = (7, 19)
    ):
        """
        Linear reward function with a time-dependent weight for consumption and energy terms.

        Args:
            env (Env): Gym environment.
            temperature_variable (Union[str, list]): Name(s) of the temperature variable(s).
            energy_variable (str): Name of the energy/power variable.
            range_comfort_winter (Tuple[int,int]): Temperature comfort range for cold season. Depends on environment you are using.
            range_comfort_summer (Tuple[int,int]): Temperature comfort range for hot season. Depends on environment you are using.
            summer_start (Tuple[int,int]): Summer session tuple with month and day start. Defaults to (6,1).
            summer_final (Tuple[int,int]): Summer session tuple with month and day end. defaults to (9,30).
            min_energy_weight (float, optional): Minimum weight given to the energy term. Defaults to 0.5.
            lambda_energy (float, optional): Constant for removing dimensions from power(1/W). Defaults to 1e-4.
            lambda_temperature (float, optional): Constant for removing dimensions from temperature(1/C). Defaults to 1.0.
            range_comfort_hours (tuple, optional): Hours where thermal comfort is considered. Defaults to (9, 19).
        """

        super(MyHourlyExpReward, self).__init__(
            env,
            temperature_variable,
            energy_variable,
            range_comfort_winter,
            range_comfort_summer,
            summer_start,
            summer_final,
            min_energy_weight,
            lambda_energy,
            lambda_temperature
        )



        # Reward parameters
        self.range_comfort_hours = range_comfort_hours

    def __call__(self) -> Tuple[float, Dict[str, Any]]:
        """Calculate the reward function.

        Returns:
            Tuple[float, Dict[str, Any]]: Reward and dict with reward terms.
            """
        # Current observation
        obs_dict = self.env.obs_dict.copy()

        # Energy term
        #reward_energy = - self.lambda_energy * obs_dict[self.energy_name]
        reward_energy = - self.lambda_energy * obs_dict['Facility Total HVAC Electricity Demand Rate(Whole Building)']
        # Comfort
        comfort, temps = self._get_comfort(obs_dict)
        reward_comfort = - self.lambda_temp * comfort

        # Determine energy weight depending on the hour
        hour = obs_dict['hour']
        if hour >= self.range_comfort_hours[0] and hour <= self.range_comfort_hours[1]:
            weight = self.W_energy
        else:
            weight = 1


        # Weighted sum of both terms
        reward = weight * reward_energy + (1.0 - weight) * reward_comfort

        reward_terms = {
            'reward_energy': reward_energy,
            'total_energy': obs_dict[self.energy_name],
            'reward_comfort': reward_comfort,
            'temperatures': temps
        }

        return reward, reward_terms

# %% [markdown]
# # create the environment and perform RL

# %%
#environment = "Eplus-demo-v1"
environment  = "Eplus-5Zone-hot-continuous-v1"
#environment = "Eplus-5Zone-mixed- continuous-v1"
weather = "USA_NY_New.York-J.F.Kennedy.Intl.AP.744860_TMY3.epw"



episodes = 10
experiment_date = datetime.today().strftime('%Y-%m-%d %H:%M')

#choose the simulation period
begin_day = 1
begin_month = 1
begin_year = 2022
end_day = 1
end_month = 2
end_year = 2022

# register run name
name = F"{environment}-episodes_{episodes}({experiment_date})"


# Set to one month only to reduce running time
extra_params={'timesteps_per_hour' : 4,
              'runperiod' : (begin_day,begin_month,begin_year,end_day,end_month,end_year)}

new_observation_variables=[
    'Site Outdoor Air Drybulb Temperature(Environment)',
    'Site Diffuse Solar Radiation Rate per Area(Environment)',
    'Site Direct Solar Radiation Rate per Area(Environment)',
    'Zone Thermostat Heating Setpoint Temperature(SPACE1-1)',
    'Zone Thermostat Cooling Setpoint Temperature(SPACE1-1)',
    'Zone Air Temperature(SPACE1-1)',
    'Zone People Occupant Count(SPACE1-1)',
    'People Air Temperature(SPACE1-1 PEOPLE 1)',
    'Facility Total HVAC Electricity Demand Rate(Whole Building)']

new_observation_space = gym.spaces.Box(
    low=-5e6,
    high=5e6,
    shape=(len(new_observation_variables) + 4,),
    dtype=np.float32)



env = gym.make(environment, 
                weather_file = weather,
                reward = MyHourlyExpReward, 
                config_params = extra_params,
                observation_variables = new_observation_variables,
                observation_space = new_observation_space)



env = LoggerWrapper(NormalizeObservation(env, ranges = RANGES_5ZONE))


#choose the algorithm and parameters you want to use
model = A2C('MlpPolicy', env, verbose=1,
    learning_rate=0.0003)


n_timesteps_episode = env.simulator._eplus_one_epi_len / env.simulator._eplus_run_stepsize

env_vec = DummyVecEnv([lambda: env])

callbacks = []

# Set up Evaluation and saving best model
eval_callback = LoggerEvalCallback(
    env_vec,
    best_model_save_path='best_model/' + name + '/',
    log_path='best_model/' + name + '/',
    eval_freq=n_timesteps_episode * 2,
    deterministic=True,
    render=False,
    n_eval_episodes=2)
callbacks.append(eval_callback)

callback = CallbackList(callbacks)

timesteps = episodes * n_timesteps_episode

model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=100)

#model.save(env.simulator._env_working_dir_parent + '/' + name)

env.close()
# Out:
# [2023-01-23 19:32:23,773] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-23 19:32:23,773] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-23 19:32:23,773] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-01-23 19:32:23,796] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-23 19:32:23,796] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-23 19:32:23,796] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-23 19:32:23,833] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-23 19:32:23,833] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-23 19:32:23,833] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-01-23 19:32:23,853] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-23 19:32:23,853] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-23 19:32:23,853] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-23 19:32:23,878] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-23 19:32:23,878] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-01-23 19:32:23,878] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# [2023-01-23 19:32:24,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:32:24,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:32:24,622] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:32:24,776] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-23 19:32:24,776] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# [2023-01-23 19:32:24,776] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run1
# ------------------------------------
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 100      |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | -0.0977  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 99       |
# |    policy_loss        | -5.8     |
# |    std                | 1.01     |
# |    value_loss         | 8        |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 200      |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | -0.00846 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 199      |
# |    policy_loss        | -9.09    |
# |    std                | 1.01     |
# |    value_loss         | 22.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 300      |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -0.00893 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 299      |
# |    policy_loss        | -4.4     |
# |    std                | 1        |
# |    value_loss         | 2.15     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 24       |
# |    iterations         | 400      |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -0.451   |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.44     |
# |    std                | 1        |
# |    value_loss         | 0.0254   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 19       |
# |    iterations         | 500      |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -0.0268  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 499      |
# |    policy_loss        | -1.87    |
# |    std                | 1        |
# |    value_loss         | 1.22     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 8        |
# |    iterations         | 600      |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | -0.0396  |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 599      |
# |    policy_loss        | -7.4     |
# |    std                | 1        |
# |    value_loss         | 6.3      |
# ------------------------------------
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [2023-01-23 19:38:41,762] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:38:41,762] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:38:41,762] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:38:41,783] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:38:41,783] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:38:41,783] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:38:41,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-23 19:38:41,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# [2023-01-23 19:38:41,895] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run2
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -3.89e+03 |
# | time/                 |           |
# |    fps                | 9         |
# |    iterations         | 700       |
# |    time_elapsed       | 388       |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | -0.000383 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 699       |
# |    policy_loss        | -9.93     |
# |    std                | 0.999     |
# |    value_loss         | 31.5      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -3.89e+03 |
# | time/                 |           |
# |    fps                | 10        |
# |    iterations         | 800       |
# |    time_elapsed       | 398       |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | -0.0112   |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 799       |
# |    policy_loss        | -2.31     |
# |    std                | 0.996     |
# |    value_loss         | 0.671     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -3.89e+03 |
# | time/                 |           |
# |    fps                | 10        |
# |    iterations         | 900       |
# |    time_elapsed       | 429       |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | 0.00015   |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 899       |
# |    policy_loss        | -6.26     |
# |    std                | 0.995     |
# |    value_loss         | 8.64      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -3.89e+03 |
# | time/                 |           |
# |    fps                | 10        |
# |    iterations         | 1000      |
# |    time_elapsed       | 467       |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -0.421    |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 999       |
# |    policy_loss        | -1.36     |
# |    std                | 0.991     |
# |    value_loss         | 0.226     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -3.89e+03 |
# | time/                 |           |
# |    fps                | 11        |
# |    iterations         | 1100      |
# |    time_elapsed       | 475       |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -0.00375  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1099      |
# |    policy_loss        | -1.99     |
# |    std                | 0.99      |
# |    value_loss         | 0.852     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -3.89e+03 |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 1200      |
# |    time_elapsed       | 483       |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.00015  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1199      |
# |    policy_loss        | -6.95     |
# |    std                | 0.988     |
# |    value_loss         | 10.8      |
# -------------------------------------
# [2023-01-23 19:40:36,551] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:40:36,551] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:40:36,551] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:40:36,570] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:40:36,570] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:40:36,570] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:40:37,014] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-23 19:40:37,014] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-23 19:40:37,014] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run3
# [2023-01-23 19:42:37,616] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:42:37,616] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:42:37,616] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:42:37,643] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:42:37,643] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:42:37,643] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:42:37,998] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-23 19:42:37,998] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-23 19:42:37,998] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run4
# [2023-01-23 19:44:22,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:44:22,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:44:22,159] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:44:22,298] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:44:22,298] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:44:22,298] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:44:22,807] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-23 19:44:22,807] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-23 19:44:22,807] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run5
# [2023-01-23 19:48:42,444] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:48:42,444] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:48:42,444] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:48:42,499] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:48:42,499] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:48:42,499] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:48:42,683] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-23 19:48:42,683] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# [2023-01-23 19:48:42,683] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run6
# Eval num_timesteps=6144, episode_reward=-7076.93 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -1.24e+04 |
# |    comfort_violation(%)   | 26        |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 1.19e+07  |
# |    mean_rewards           | -7076.931 |
# |    power_penalty          | -1.19e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -4.65e+03 |
# | time/                     |           |
# |    fps                    | 6         |
# |    iterations             | 1300      |
# |    time_elapsed           | 986       |
# |    total_timesteps        | 6500      |
# | train/                    |           |
# |    entropy_loss           | -2.81     |
# |    explained_variance     | -0.00144  |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 1299      |
# |    policy_loss            | 0.359     |
# |    std                    | 0.987     |
# |    value_loss             | 0.038     |
# -----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -4.65e+03 |
# | time/                 |           |
# |    fps                | 7         |
# |    iterations         | 1400      |
# |    time_elapsed       | 999       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.00579  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.218    |
# |    std                | 0.985     |
# |    value_loss         | 0.00878   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -4.65e+03 |
# | time/                 |           |
# |    fps                | 7         |
# |    iterations         | 1500      |
# |    time_elapsed       | 1068      |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.000313 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1499      |
# |    policy_loss        | -2.01     |
# |    std                | 0.985     |
# |    value_loss         | 1.13      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -4.65e+03 |
# | time/                 |           |
# |    fps                | 7         |
# |    iterations         | 1600      |
# |    time_elapsed       | 1079      |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.000493 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1599      |
# |    policy_loss        | -1.39     |
# |    std                | 0.986     |
# |    value_loss         | 0.346     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -4.65e+03 |
# | time/                 |           |
# |    fps                | 7         |
# |    iterations         | 1700      |
# |    time_elapsed       | 1088      |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 2.42e-05  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1699      |
# |    policy_loss        | 1.56      |
# |    std                | 0.987     |
# |    value_loss         | 0.267     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -4.65e+03 |
# | time/                 |           |
# |    fps                | 8         |
# |    iterations         | 1800      |
# |    time_elapsed       | 1101      |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -1.62e-05 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1799      |
# |    policy_loss        | -5.94     |
# |    std                | 0.988     |
# |    value_loss         | 6.53      |
# -------------------------------------
# [2023-01-23 19:50:57,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:50:57,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:50:57,039] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:50:57,107] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:50:57,107] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:50:57,107] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:50:57,954] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-23 19:50:57,954] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# [2023-01-23 19:50:57,954] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run7
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.43e+03 |
# | time/                 |           |
# |    fps                | 8         |
# |    iterations         | 1900      |
# |    time_elapsed       | 1177      |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.000706 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.717     |
# |    std                | 0.985     |
# |    value_loss         | 0.135     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.43e+03 |
# | time/                 |           |
# |    fps                | 8         |
# |    iterations         | 2000      |
# |    time_elapsed       | 1185      |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.00329  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.133    |
# |    std                | 0.988     |
# |    value_loss         | 0.0036    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.43e+03 |
# | time/                 |           |
# |    fps                | 8         |
# |    iterations         | 2100      |
# |    time_elapsed       | 1193      |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2099      |
# |    policy_loss        | -602      |
# |    std                | 0.987     |
# |    value_loss         | 4.13e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.43e+03 |
# | time/                 |           |
# |    fps                | 9         |
# |    iterations         | 2200      |
# |    time_elapsed       | 1201      |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -0.00012  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2199      |
# |    policy_loss        | 2.51      |
# |    std                | 0.988     |
# |    value_loss         | 0.51      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.43e+03 |
# | time/                 |           |
# |    fps                | 9         |
# |    iterations         | 2300      |
# |    time_elapsed       | 1229      |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -1.19e-05 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2299      |
# |    policy_loss        | 1.73      |
# |    std                | 0.987     |
# |    value_loss         | 0.741     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.43e+03 |
# | time/                 |           |
# |    fps                | 9         |
# |    iterations         | 2400      |
# |    time_elapsed       | 1303      |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | 2.97e-05  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.837    |
# |    std                | 0.987     |
# |    value_loss         | 0.12      |
# -------------------------------------
# [2023-01-23 19:54:17,680] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:54:17,680] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:54:17,680] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:54:17,697] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:54:17,697] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:54:17,697] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:54:18,057] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-23 19:54:18,057] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-23 19:54:18,057] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run8
# [2023-01-23 19:54:27,075] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:54:27,075] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:54:27,075] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 19:54:27,094] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:54:27,094] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:54:27,094] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 19:54:27,460] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-23 19:54:27,460] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-23 19:54:27,460] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run9
# [2023-01-23 20:07:05,678] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:07:05,678] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:07:05,678] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:07:05,720] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:07:05,720] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:07:05,720] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:07:05,939] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-23 20:07:05,939] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-23 20:07:05,939] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run10
# [2023-01-23 20:07:50,570] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:07:50,570] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:07:50,570] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:07:50,591] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:07:50,591] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:07:50,591] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:07:51,292] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-23 20:07:51,292] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# [2023-01-23 20:07:51,292] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run11
# Eval num_timesteps=12288, episode_reward=-7076.93 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -1.24e+04 |
# |    comfort_violation(%)   | 26        |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 1.19e+07  |
# |    mean_rewards           | -7076.931 |
# |    power_penalty          | -1.19e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -5.8e+03  |
# | time/                     |           |
# |    fps                    | 5         |
# |    iterations             | 2500      |
# |    time_elapsed           | 2144      |
# |    total_timesteps        | 12500     |
# | train/                    |           |
# |    entropy_loss           | -2.81     |
# |    explained_variance     | 0.000845  |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 2499      |
# |    policy_loss            | -2.53     |
# |    std                    | 0.988     |
# |    value_loss             | 0.68      |
# -----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.8e+03  |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 2600      |
# |    time_elapsed       | 2351      |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -2.26e-06 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2599      |
# |    policy_loss        | -117      |
# |    std                | 0.99      |
# |    value_loss         | 1.84e+03  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -5.8e+03  |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 2700      |
# |    time_elapsed       | 2360      |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -2.36e-05 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 2699      |
# |    policy_loss        | 2.26      |
# |    std                | 0.992     |
# |    value_loss         | 0.935     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -5.8e+03 |
# | time/                 |          |
# |    fps                | 5        |
# |    iterations         | 2800     |
# |    time_elapsed       | 2368     |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | 1.01e-05 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2799     |
# |    policy_loss        | 2.33     |
# |    std                | 0.993    |
# |    value_loss         | 1        |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -5.8e+03 |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2900     |
# |    time_elapsed       | 2377     |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | 9.66e-06 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2899     |
# |    policy_loss        | 1.99     |
# |    std                | 0.99     |
# |    value_loss         | 0.614    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -5.8e+03 |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3000     |
# |    time_elapsed       | 2395     |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | 0.000318 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.387    |
# |    std                | 0.989    |
# |    value_loss         | 0.0261   |
# ------------------------------------
# [2023-01-23 20:14:22,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:14:22,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:14:22,443] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:14:22,475] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:14:22,475] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:14:22,475] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:14:22,994] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-23 20:14:22,994] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# [2023-01-23 20:14:22,994] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run12
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.03e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3100      |
# |    time_elapsed       | 2528      |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -8.34e-07 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3099      |
# |    policy_loss        | -140      |
# |    std                | 0.992     |
# |    value_loss         | 1.7e+03   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.03e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3200      |
# |    time_elapsed       | 2536      |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -1.72e-05 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.947     |
# |    std                | 0.99      |
# |    value_loss         | 0.184     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.03e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3300      |
# |    time_elapsed       | 2544      |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 2.31e-05  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3299      |
# |    policy_loss        | 3.49      |
# |    std                | 0.992     |
# |    value_loss         | 1.03      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.03e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3400      |
# |    time_elapsed       | 2557      |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -0.000785 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3399      |
# |    policy_loss        | 0.788     |
# |    std                | 0.991     |
# |    value_loss         | 0.185     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.03e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3500      |
# |    time_elapsed       | 2598      |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 3.51e-05  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.59      |
# |    std                | 0.993     |
# |    value_loss         | 0.189     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.03e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3600      |
# |    time_elapsed       | 2610      |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 3599      |
# |    policy_loss        | -0.532    |
# |    std                | 0.991     |
# |    value_loss         | 0.341     |
# -------------------------------------
# [2023-01-23 20:16:03,295] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:16:03,295] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:16:03,295] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:16:03,307] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:16:03,307] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:16:03,307] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:16:03,883] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-23 20:16:03,883] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-23 20:16:03,883] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run13
# [2023-01-23 20:16:13,068] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:16:13,068] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:16:13,068] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:16:13,081] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:16:13,081] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:16:13,081] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:16:13,363] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-23 20:16:13,363] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-23 20:16:13,363] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run14
# [2023-01-23 20:18:08,448] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:18:08,448] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:18:08,448] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:18:08,565] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:18:08,565] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:18:08,565] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:18:09,106] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run15
# ...
# Eval num_timesteps=24576, episode_reward=-7076.93 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    comfort_penalty        | -1.24e+04 |
# |    comfort_violation(%)   | 26        |
# |    mean_ep_length         | 3.07e+03  |
# |    mean_power_consumption | 1.19e+07  |
# |    mean_rewards           | -7076.931 |
# |    power_penalty          | -1.19e+03 |
# |    std_rewards            | 0.0       |
# | rollout/                  |           |
# |    ep_len_mean            | 3.07e+03  |
# |    ep_rew_mean            | -6.42e+03 |
# | time/                     |           |
# |    fps                    | 6         |
# |    iterations             | 5000      |
# |    time_elapsed           | 3752      |
# |    total_timesteps        | 25000     |
# | train/                    |           |
# |    entropy_loss           | -2.8      |
# |    explained_variance     | -8.34e-07 |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 4999      |
# |    policy_loss            | -210      |
# |    std                    | 0.98      |
# |    value_loss             | 8.98e+03  |
# -----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.42e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 5100      |
# |    time_elapsed       | 4407      |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | -6.44e-06 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5099      |
# |    policy_loss        | 0.169     |
# |    std                | 0.982     |
# |    value_loss         | 0.109     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.42e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 5200      |
# |    time_elapsed       | 4416      |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -2.79     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5199      |
# |    policy_loss        | -65.5     |
# |    std                | 0.977     |
# |    value_loss         | 386       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.42e+03 |
# | time/                 |           |
# |    fps                | 5         |
# |    iterations         | 5300      |
# |    time_elapsed       | 4425      |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | 2.1e-05   |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.62      |
# |    std                | 0.98      |
# |    value_loss         | 0.25      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.42e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5400      |
# |    time_elapsed       | 4436      |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | -3.96e-05 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5399      |
# |    policy_loss        | -1.18     |
# |    std                | 0.982     |
# |    value_loss         | 0.164     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.42e+03 |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5500      |
# |    time_elapsed       | 4466      |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5499      |
# |    policy_loss        | -34       |
# |    std                | 0.982     |
# |    value_loss         | 419       |
# -------------------------------------
# [2023-01-23 20:47:29,484] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:47:29,484] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:47:29,484] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:47:29,657] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:47:29,657] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:47:29,657] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:47:30,970] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run22
# [2023-01-23 20:47:30,970] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run22
# [2023-01-23 20:47:30,970] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run22
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.5e+03  |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5600      |
# |    time_elapsed       | 4531      |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -2.8      |
# |    explained_variance | -1.16e-05 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5599      |
# |    policy_loss        | 1.93      |
# |    std                | 0.983     |
# |    value_loss         | 0.404     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.07e+03  |
# |    ep_rew_mean        | -6.5e+03  |
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5700      |
# |    time_elapsed       | 4540      |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -2.81     |
# |    explained_variance | -2.03e-06 |
# |    learning_rate      | 0.0003    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.999    |
# |    std                | 0.987     |
# |    value_loss         | 8         |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -6.5e+03 |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5800     |
# |    time_elapsed       | 4549     |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | 0.000225 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5799     |
# |    policy_loss        | -2.02    |
# |    std                | 0.99     |
# |    value_loss         | 0.663    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -6.5e+03 |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5900     |
# |    time_elapsed       | 4570     |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 1.93e-05 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.834    |
# |    std                | 0.988    |
# |    value_loss         | 0.0705   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -6.5e+03 |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6000     |
# |    time_elapsed       | 4839     |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.961    |
# |    std                | 0.987    |
# |    value_loss         | 0.151    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07e+03 |
# |    ep_rew_mean        | -6.5e+03 |
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6100     |
# |    time_elapsed       | 4851     |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 1.73e-06 |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 6099     |
# |    policy_loss        | -5.19    |
# |    std                | 0.986    |
# |    value_loss         | 4.05     |
# ------------------------------------
# [2023-01-23 20:53:22,277] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:53:22,277] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:53:22,277] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:53:22,285] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:53:22,285] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:53:22,285] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:53:23,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run23
# [2023-01-23 20:53:23,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run23
# [2023-01-23 20:53:23,123] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run23
# [2023-01-23 20:53:38,151] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:53:38,151] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:53:38,151] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:53:38,168] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:53:38,168] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:53:38,168] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:53:38,552] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run24
# [2023-01-23 20:53:38,552] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run24
# [2023-01-23 20:53:38,552] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run24
# [2023-01-23 20:58:30,016] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:58:30,016] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:58:30,016] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 20:58:30,034] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:58:30,034] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:58:30,034] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 20:58:30,388] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run25
# [2023-01-23 20:58:30,388] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run25
# [2023-01-23 20:58:30,388] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run25
# [2023-01-23 21:01:44,221] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 21:01:44,221] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 21:01:44,221] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-23 21:01:44,425] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 21:01:44,425] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 21:01:44,425] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-23 21:01:46,140] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run26
# [2023-01-23 21:01:46,140] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run26
# [2023-01-23 21:01:46,140] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /workspaces/sinergym/examples/Eplus-env-5Zone-hot-continuous-v1-res1/Eplus-env-sub_run26
# Eval num_timesteps=30720, episode_reward=-7076.93 +/- 0.00
# Episode length: 3072.00 +/- 0.00
# [2023-01-23 21:02:10,560] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-23 21:02:10,560] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
# [2023-01-23 21:02:10,560] EPLUS_ENV_5Zone-hot-continuous-v1_MainThread_ROOT INFO:EnergyPlus simulation closed successfully.
